# %% [markdown]
# # Campus Opportunity Radar — Data Exploration
#
# This notebook explores the synthetic data and validates the Opportunity Graph structure.
#
# **Will be populated after data generation in Phase 1.**

# %%
# Placeholder — Phase 1
print('Data exploration notebook ready for Phase 1')
